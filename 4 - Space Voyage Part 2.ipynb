# %% [markdown]
# # Space Voyage: Part 2
#
# ### Objectives
# In this program, you will model the motion of a spacecraft traveling from the Earth to the Moon. To do this, you will iteratively (repeatedly):
#
# - calculate the gravitational force on the spacecraft by the Earth and the Moon
# - apply the Momentum Principle to update the momentum of the spacecraft
# - update the position of the spacecraft
#
# ### Goals
# You will use your working program to:
#
# - explore the effect of the spacecraft's initial velocity on its trajectory
# - study the effect of your choice of $\Delta t$ (deltat/dt) on the accuracy of your predictions
#
# ### Part 1: Programming
# In the real world, the net force on a spacecraft is rarely due to only one other object. By adding the Moon to your program below, you will get to observe the kind of complex motion that the interaction of three or more objects can produce. Below is an outline of the program you should start editing.
#
# - Create a sphere to represent the Moon. Make its initial location $4e8 m$ to the right of the Earth.
# - Carefully consider how you will define the `scalefactor` so that you will be able to see all three objects in the display. (What distance should you use for `physicalmax`?)
# - Run your program (you should see the craft, the Earth, and the Moon)
# - Inside your `while` loop, add a calculation of the gravitational force that the Moon AND the Earth exert on the spacecraft, and calculate the net force (check your Space Voyage Part 1 notebook).
# - Use the net force to update the momentum of the spacecraft. We will use the simplifying assumption that both the Earth and the Moon are fixed in position.
# - Add a check for crashing on the Moon, like your check for crashing on the Earth.
# - Adjust `dt` and `time_limit` so the step size is 10 seconds and the loop time is 60 days to follow the more complicated orbits that can occur.
# - Run your program (you should see an orbit).

# %%
from vpython import *
# Out:
# <div id="glowscript" class="glowscript"></div>

# %%
current = 0
current = canvas.get_selected()
if current != 0:
    current.delete()
# --------------------
# Scene setup 
# --------------------
intro_scene = canvas() # set the variable intro_scene to "hold" our canvas
intro_scene.title = "Space Voyage Part 2" # set the title
intro_scene.width = 800 # specify the width
intro_scene.height = 600 # specify the height
intro_scene.background = color.black # set the background to the desired color



# --------------------
# constants
# -------------------
G = 6.7e-11

# earth constants
mEarth = 6e24
rEarth = 6.4e6
planetloc = vector(0,0,0)

# craft constants
mcraft = 15e3
craftloc = vector(-10*rEarth, 0, 0)
craft_radius = 0.15

# moon constants
mMoon = 7e22
rMoon = 1.75e6
Moonloc = ??? # should be a vector

# define all constants relating to time

t = 0
dt = 60
frames = 100
time_limit = 10*365*24*60*60 # Provide a limit for the while loop to stop

# --------------------
# display setup
# --------------------
displaymax = 10
intro_scene.range = displaymax


physicalmax = mag(???) # CHANGE THIS
scalefactor = displaymax/physicalmax


# --------------------
# create display objects
# --------------------

Earth = sphere(
    pos = planetloc, 
    radius = rEarth*scalefactor, 
    texture = "https://i.imgur.com/do31Gdf.jpg", 
    canvas = intro_scene # NEED TO CHANGE AFTER YOU COPY
    )

craft = sphere(
    pos = craftloc * scalefactor,
    radius = craft_radius,
    color = color.yellow,
    make_trail = True,
    canvas = intro_scene
    )

Moon = 

# --------------------
# initial values
# --------------------
vcraft = vector(0, 2e3, 0) # initial velocity is straight up along y
pcraft = mcraft * vcraft


# --------------------
# CALCULATION LOOP: ALL REPEATED CALCULATIONS GO INSIDE THE LOOP 
# --------------------
while t < time_limit and t > -1:
    rate(frames) # slow down motion to make animation look nicer

    # PUT YOUR CODE FOR GRAVITY HERE

    craftloc += (pcraft/mcraft) * dt

    t += dt
    
    ### Check if we want to exit ###
    k = keysdown()

    if 'q' in k:
        # can change the code to just stop the while loop
        intro_scene.delete() # delete the scene (closes the scene of the spacecraft and Earth)
        break # break out of the while loop

    
print("All done") # print a message that everything is deleted

# %% [markdown]
# ### Part 2: Different Orbits
# Find initial velocities that produce the following trajectories. Record each one in a markdown cell at the bottom of the notebook.
#
# - Spaceship crashes on the Moon
# - Elliptical orbit around both the Earth and the Moon
# - "Figure-8" orbit that loops around the Moon before returning to Earth
# - A different, interesting orbit
#
# How sensitive are these initial velocities? How much can you change the initial velocity and still get a figure-8 orbit?
#
# When the spacecraft interacted solely with the Earth (a "two-body" interaction), there were only a few kinds of orbits possible, and they were quite simple curves (circle, ellipse, parabola, hyperbola, straight line).  Small changes in the initial velocity typically led to small changes in the orbit.  For example, an ellipse merely became a longer ellipse with a larger initial speed.
#
# In the “three-body” interaction of Earth, Moon and spacecraft, there is a much larger variety of orbits.  If just three bodies show complex behavior, no wonder a macroscopic system such as you is highly complex, since you contain an astronomical number of interaction atoms!
#
# Also, an extremely slight change in the initial velocity can make a major change in the motion: the orbit is highly sensitive to the initial velocity. The rich variety of types of motion and the high sensitivity to initial velocity are typical of complex systems. This is the subject of the relatively new science of “chaos.” See the discussion of these matters on pages 117-121 in the textbook.

# %% [markdown]
# #### Answers to the above questions:

# %% [markdown]
# ### Answer these questions about a particularly interesting trajectory
#
# Give the spacecraft a speed of $3.27$ $km/s$ ($3.27\text{e}3$ $m/s$), headed in the $+y$ direction. What happens?
#
# Why does coming nearly to a stop lead to retracing the path? Explain in terms of the Momentum Principle and the gravitational force law.
#
# Discuss your results and answers with those of a nearby group.

# %% [markdown]
# #### Answer here:

# %% [markdown]
# ### Part 3: Accuracy
#
# If you use a very large $\Delta t$, the calculation is inaccurate, because during that large time interval, the force changes a lot, making the momentum update inaccurate. On the other hand, if you use a very small $\Delta t$ for high accuracy, the program runs very slowly. In computational modeling, there is a trade-off between accuracy and speed.
#
# How can you tell whether an orbit is accurate? There's a simple test: Make $\Delta t$ smaller and see whether the motion changes. That is, see whether the orbit changes shape (the program will run more slowly).
#
# - You've been using a step size of 10 seconds. Try a step size one-fifth as large (2 seconds). With an initial speed of $3.27 km/s$, is the orbit the same? If the orbit is the same using this smaller step size, that implies that a step size less than or equal to $10$ seconds is adequately short to give accurate results.
# - To see the effects of $\Delta t$ being too large, make $\Delta t$ $100$ times as large as you had been using ($1000$ seconds).
#
# #### Answer these questions about the effect of step size on accuracy
#
# 1. Does the $10$ second step size give an accurate orbit? How do you know?
# 2. Why does the large step size ($1000$ seconds) give an inaccurate orbit?
#
# Discuss your answers with those of a nearby group. After checking with another group, ask the instructor to check your work.
#
# #### Answer here:

# %% [markdown]
# ##### Before turning in your program restore it to the following state:
# - $10$ second step size
# - initial spped of spacecraft $3.27e3 m/s$ in the $+y$ direction
#  **Show your program to your TA**

# %% [markdown]
# ### [Optional] Playing arround
#
# Shoot the spacecraft straight toward the Moon from near the surface of the Earth, starting at location `(1.01 * Earth.radius, 0, 0)`, with an initial speed of $11 km/s$. What happens? Why? What happens if you increase or decrease the initial speed? It’s interesting to watch the momentum vector and think about the effects of the forces on the momentum during this motion.
#
# You can make a more realistic model if you let the Moon and Earth orbit each other while the spacecraft is moving. Calculate all the forces among the three bodies, then update all of the momenta before updating any of the positions. That way you calculate the forces in a consistent way at a particular instant.  You will have to experiment a bit with the initial velocity to get the nearly circular orbit of the Moon around the Earth (the Earth follows a nearly circular orbit, too, but it is only a small wobble because the Earth’s mass is much larger than the Moon’s mass.)
#
# You have explored complex motions with three objects all moving.  Now copy your program under a new name and try something different.  Make the mass and size of each object equal.  Can you create a stable system?  That is, can you create a system in which the orbiting motion of all three objects repeats itself?
#
# You might also try to model the Sun-Earth-Moon system, with or without the spacecraft. A practical difficulty with visualizing the Sun-Earth-Moon system is that the Earth-Moon system is very small compared to the great distance to the Sun, so it’s hard to see the details of the Moon’s motion. However, you can continually update the center of the scene by resetting `scene.center` inside the loop to follow the Earth-Moon system, and zoom in on this region. Alternatively, you can set `intro_scene.autocenter = True`, which makes the centering automatic.
